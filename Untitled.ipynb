# %%
from qiskit import *

# %%
circuit = QuantumCircuit.from_qasm_file("qasm_files/ult.qasm")

# %%
circuit.draw()
# Out:
#       ┌───┐     ┌──────┐                                                     »
# q2_0: ┤ H ├─────┤2     ├───────■─────────■───────────────────────────────────»
#       ├───┤     │      │       │         │                                   »
# q2_1: ┤ H ├─────┤      ├───────┼─────────┼────■─────────■────────────────────»
#       ├───┤┌───┐│      │       │         │    │  ┌───┐  │  ┌──────┐          »
# q3_0: ┤ H ├┤ X ├┤      ├──■────┼────■────┼────┼──┤ X ├──┼──┤2     ├──■────■──»
#       ├───┤├───┤│      │  │    │  ┌─┴─┐  │    │  └───┘  │  │      │  │    │  »
# q3_1: ┤ H ├┤ X ├┤      ├──■────┼──┤ X ├──┼────┼─────────┼──┤      ├──┼────┼──»
#       └───┘└───┘│      │  │    │  └───┘  │  ┌─┴─┐┌───┐  │  │      │  │    │  »
#   q4: ──────────┤3 mcx ├──┼────┼─────────┼──┤ X ├┤ X ├──┼──┤3     ├──┼────┼──»
#                 │      │  │    │         │  └─┬─┘└─┬─┘  │  │      │  │    │  »
# an_0: ──────────┤      ├──┼────┼─────────┼────┼────■────┼──┤  mcx ├──┼────┼──»
# ...
